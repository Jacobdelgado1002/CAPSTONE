# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ### Import Libraries

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# import keras_tuner as kt
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.utils.class_weight import compute_class_weight

# %%
# import os
# import shutil

# def merge_folders(input_root, output_root):
#     # Create the output directory if it doesn't exist
#     if not os.path.exists(output_root):
#         os.makedirs(output_root)
    
#     # Loop through each fold (e.g. FOLD1, FOLD2, etc.)
#     for fold in os.listdir(input_root):
#         fold_path = os.path.join(input_root, fold)
#         fold_path = os.path.join(fold_path, "Test")
#         if not os.path.isdir(fold_path):
#             continue  # Skip files; expect only folders here

#         # For each category folder inside the fold
#         for category in os.listdir(fold_path):
#             category_path = os.path.join(fold_path, category)
#             if not os.path.isdir(category_path):
#                 continue  # Skip non-directory items
            
#             # Create the corresponding category folder in the output if it doesn't exist
#             output_category_path = os.path.join(output_root, category)
#             if not os.path.exists(output_category_path):
#                 os.makedirs(output_category_path)
            
#             # Copy each file from the category folder to the merged output only if it doesn't exist already
#             for file_name in os.listdir(category_path):
#                 file_path = os.path.join(category_path, file_name)
#                 if os.path.isfile(file_path):
#                     destination = os.path.join(output_category_path, file_name)
#                     if os.path.exists(destination):
#                         print(f"Skipped {file_path} because {destination} already exists.")
#                     else:
#                         shutil.copy(file_path, destination)
#                         print(f"Copied {file_path} to {destination}")

# # Example usage:
# # merge_folders("../data/MSLDV2/Augmented Images/Augmented Images/FOLDS_AUG", "../data/merged_MSLD/Train")
# merge_folders("../data/MSLDV2/Original Images/Original Images/FOLDS", "../data/merged_MSLD/Test")

# %% [markdown]
# ## Train with Skin Cancer Dataset

# %% [markdown]
# ### Hyperparameters

# %%
data_root = pathlib.Path("../data/merged_MSLD/Train")    # points to the folder containing the images that will be used for training

# hyperparameters
img_height = 224        # input image height
img_width = 224         # input image width
batch_size = 32         # size of the batch that will be fed to model

# folds = the amount of folds that will be created for cross-validation
# fine_tune_epochs = number of epochs after which we start fine-tuning
# fine_tune_at = layer number where we start unfreezing layers

# configurations that will be used in training
configs = [
    {"model_name": "mobilenet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
    # {"model_name": "mobilenet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": True, "fine_tune_epochs": 25, "fine_tune_at": 148},
    # {"model_name": "mobilenet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
    # {"model_name": "mobilenet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": True, "fine_tune_epochs": 25, "fine_tune_at": 148},

    {"model_name": "efficientnet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
    
    {"model_name": "densenet", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},

    {"model_name": "inceptionv3", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},

    {"model_name": "resnet50", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},

    {"model_name": "vgg16", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 15},

    # {"model_name": "xception", "learning_rate": 0.001, "batch_size": 32, "image_size" : 224, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
]

# Define the base path for saving models
save_dir = "../saved_models"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Setup

# %%
# Load dataset without splitting
dataset = tf.keras.utils.image_dataset_from_directory(
    data_root,                                  # loads images from the data_root directory
    image_size=(img_height, img_width),         # resizes all images to (224, 224) pixels
    batch_size=batch_size,                      # set the batch size
    shuffle=True                                # shufle data when loaded
)

# test_ds = tf.keras.utils.image_dataset_from_directory(
#     "../data/merged_MSLD/Test",                                  # loads images from the data_root directory
#     image_size=(img_height, img_width),         # resizes all images to (224, 224) pixels
#     batch_size=batch_size,                      # set the batch size
#     shuffle=False,                              # shufle data when loaded
# )

# test_ds = test_ds.unbatch().batch(batch_size, drop_remainder=True)

class_names = np.array(dataset.class_names)     # get the class names for the data
num_classes = len(class_names)                  # get the number of classes in the dataset

# convert the dataset to a list of (image, label) pairs. This makes it easier to perform cross-validation
image_paths, labels = [], []
for image_batch, label_batch in dataset:
    image_paths.extend(image_batch.numpy())
    labels.extend(label_batch.numpy())

image_paths = np.array(image_paths)             # convert to numpy array to facilitate training
labels = np.array(labels)                       # convert to numpy array to facilitate training

# Split the dataset into training/validation and test sets
train_val_images, test_images, train_val_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.10, random_state=42, stratify=labels
)

# train_val_images = np.concatenate((train_val_images, test_images), axis=0)
# train_val_labels = np.concatenate((train_val_labels, test_labels), axis=0)


print(len(train_val_images))
print(len(train_val_labels))

def callbacks_setup(checkpoint_filepath):
    # EarlyStopping callback configuration
    early_stopping = EarlyStopping(
        monitor='val_loss',        # monitor validation loss
        patience=6,                # number of epochs with no improvement to stop training
        mode = 'min',              # want to minimize what it being monitored 
        min_delta=0.0003,
        restore_best_weights=False # don't restore in EarlyStopping, handled by ModelCheckpoint
    )

    model_checkpoint = ModelCheckpoint(
        filepath=checkpoint_filepath,   # path to save weights
        save_weights_only=True,         # only save weights instead of full model
        monitor='val_loss',             # monitor validation loss
        mode='min',                     # want to maximize what is being monitored
        save_best_only=True             # save the best weights
    )            

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',      # monitor validation loss 
        factor=0.5,              # factor by which the learning rate will be reduced 
        patience=4,              # number of epochs with no improvement to stop training 
        mode='min',              # want to minimize what it being monitored 
        min_delta=0.0003,
        min_lr=1e-6              # lower bound on the learning rate 
    )            

    return early_stopping, model_checkpoint, reduce_lr
# Out:
# Found 10570 files belonging to 6 classes.
# 9513
# 9513

# %% [markdown]
# ### Metrics

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from typing import Tuple, Dict, Any, List
from sklearn.metrics import (
    precision_score,
    classification_report,
    roc_auc_score,
    roc_curve,
    auc,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)
from sklearn.preprocessing import label_binarize

def save_confusion_matrix(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                          class_names: List[str], save_path: str) -> None:
    """
    Plots and saves the confusion matrix for multi-class classification.

    Args:
        true_labels (np.ndarray): Array of true class labels.
        predicted_labels (np.ndarray): Array of predicted class labels.
        class_names (List[str]): List of class names corresponding to class indices.
        save_path (str): Path to save the confusion matrix plot.
    """
    # Compute confusion matrix using sklearn
    cm = confusion_matrix(true_labels, predicted_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

    # Plot with adjustments
    fig, ax = plt.subplots(figsize=(8, 6))  # Adjust figure size
    disp.plot(cmap=plt.cm.Blues, ax=ax)

    ax.set_title("Confusion Matrix")
    ax.set_xlabel("Predicted label", fontsize=12)
    ax.set_ylabel("True label", fontsize=12)

    # Rotate x-axis labels for better readability and alignment
    plt.xticks(rotation=45, ha='right', rotation_mode='anchor', fontsize=10)
    plt.yticks(rotation=45, ha='right', rotation_mode='anchor', fontsize=10)

    # Prevent labels from being cut off
    plt.tight_layout()

    # Save and close plot
    plt.savefig(save_path, bbox_inches='tight')
    plt.close()

def save_loss_curve(history: Dict[str, Any], save_path: str) -> None:
    """
    Plots and saves the training and validation loss curves.

    Args:
        history (Dict[str, Any]): Dictionary containing training history (loss values).
        save_path (str): Path to save the loss curve plot.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Training Loss', color='blue')
    plt.plot(history['val_loss'], label='Validation Loss', color='orange')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig(save_path)
    plt.close()

def save_roc_auc(true_labels: np.ndarray, predicted_probs: np.ndarray, class_names: list, save_path: str = None):
    """
    Plots and saves the ROC AUC curve for multi-class classification.
    
    Args:
        true_labels (np.ndarray): True class labels.
        predicted_probs (np.ndarray): Predicted class probabilities.
        class_names (list): List of class names.
        save_path (str, optional): Path to save the ROC curve plot. Defaults to None.
    """
    plt.figure(figsize=(10, 6))
    for i, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(true_labels == i, predicted_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC AUC Curve')
    plt.legend(loc='lower right')
    
    if save_path:
        plt.savefig(save_path)
        plt.close()
    else:
        plt.show()

def save_evaluation_metrics(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                            predicted_probs: np.ndarray, save_path: str) -> Dict[str, float]:
    """
    Computes evaluation metrics for multi-class classification and saves a bar chart.
    The metrics include accuracy, precision, recall, F1 score, and ROC AUC.

    Args:
        true_labels (np.ndarray): Array of true class labels.
        predicted_labels (np.ndarray): Array of predicted class labels.
        predicted_probs (np.ndarray): Array of predicted probabilities (shape: [n_samples, n_classes]).
        save_path (str): Path to save the evaluation metrics bar chart.

    Returns:
        Dict[str, float]: Dictionary containing computed metrics.
    """
    # Calculate accuracy by comparing predicted and true labels
    accuracy = np.mean(predicted_labels == true_labels)
    # Compute macro-averaged metrics for multi-class classification
    recall = recall_score(true_labels, predicted_labels, average='macro')
    precision = precision_score(true_labels, predicted_labels, average='macro')
    f1 = f1_score(true_labels, predicted_labels, average='macro')

    # For ROC AUC, first binarize the true labels to one-hot encoding
    n_classes = predicted_probs.shape[1]
    true_labels_binarized = label_binarize(true_labels, classes=list(range(n_classes)))
    # Compute ROC AUC with a one-vs-rest approach and macro average
    roc_auc = roc_auc_score(true_labels_binarized, predicted_probs, multi_class='ovr', average='macro')

    # Store metrics in a dictionary
    metrics = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Sensitivity (Recall)": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc
    }

    # Plot metrics as a bar chart
    plt.figure(figsize=(10, 6))
    bars = plt.bar(metrics.keys(), metrics.values(), 
                   color=['darkturquoise', 'sandybrown', 'hotpink', 'limegreen', 'mediumpurple'])
    # Annotate each bar with its value
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.4f}', ha='center', va='bottom')
    plt.title("Model Evaluation Metrics")
    plt.ylim([0, 1])
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.ylabel("Score")
    plt.savefig(save_path)
    plt.close()

    return metrics

def save_classification_report(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                               class_names: List[str], save_path: str) -> None:
    """
    Saves the classification report to a text file for multi-class classification.

    Args:
        true_labels (np.ndarray): Array of true class labels.
        predicted_labels (np.ndarray): Array of predicted class labels.
        class_names (List[str]): List of class names.
        save_path (str): Path to save the classification report.
    """
    report = classification_report(true_labels, predicted_labels, target_names=class_names, digits=4)
    with open(save_path, "w") as f:
        f.write(report)

def calculate_metrics(true_labels: np.ndarray, predictions: np.ndarray) -> Tuple[float, float, float, float, float]:
    """
    Calculates evaluation metrics for multi-class classification.

    Args:
        true_labels (np.ndarray): Array of true class labels.
        predictions (np.ndarray): Array of predicted probabilities (shape: [n_samples, n_classes]).

    Returns:
        Tuple[float, float, float, float, float]: A tuple containing accuracy, precision, recall, 
            F1 score, and ROC AUC score.
    """
    # Convert predicted probabilities to predicted class labels using argmax
    predicted_labels = np.argmax(predictions, axis=1)
    accuracy = np.mean(predicted_labels == true_labels)
    precision = precision_score(true_labels, predicted_labels, average='macro')
    recall = recall_score(true_labels, predicted_labels, average='macro')
    f1 = f1_score(true_labels, predicted_labels, average='macro')

    # Binarize true labels for ROC AUC calculation
    n_classes = predictions.shape[1]
    true_labels_binarized = label_binarize(true_labels, classes=list(range(n_classes)))
    auc = roc_auc_score(true_labels_binarized, predictions, multi_class='ovr', average='macro')

    return accuracy, precision, recall, f1, auc

def save_best_model_visuals(history: tf.keras.callbacks.History, model: tf.keras.Model, 
                              val_ds: tf.data.Dataset, class_names: List[str], 
                              weights_path: str, fold: int) -> None:
    """
    Generates and saves evaluation visuals including confusion matrix, loss curve, evaluation 
    metrics bar chart, and classification report for the best performing model in a given fold.

    Args:
        history (tf.keras.callbacks.History): Training history object.
        model (tf.keras.Model): Trained model.
        val_ds (tf.data.Dataset): Validation dataset.
        class_names (List[str]): List of class names.
        weights_path (str): Directory path to save visuals.
        fold (int): Current fold number.
    """
    # Generate predictions (predicted probabilities) for the validation set
    val_predictions = model.predict(val_ds)
    # Convert predicted probabilities to class labels using argmax
    val_predicted_ids = np.argmax(val_predictions, axis=1)
    # Concatenate true labels from the validation dataset
    true_labels = np.concatenate([y for _, y in val_ds], axis=0)

    # Save the confusion matrix
    confusion_matrix_path = os.path.join(weights_path, f"confusion_matrix.png")
    save_confusion_matrix(true_labels, val_predicted_ids, class_names, confusion_matrix_path)

    # Save the loss curve using the training history
    loss_curve_path = os.path.join(weights_path, f"loss_curve.png")
    save_loss_curve(history.history, loss_curve_path)

    # Save the roc auc curve using the training history
    roc_auc_curve_path = os.path.join(weights_path, f"roc_auc_curve.png")
    save_roc_auc(true_labels, val_predictions, class_names, roc_auc_curve_path)

    # Save evaluation metrics bar chart (passing predicted probabilities for ROC AUC calculation)
    metrics_bar_chart_path = os.path.join(weights_path, f"evaluation_metrics.png")
    save_evaluation_metrics(true_labels, val_predicted_ids, val_predictions, metrics_bar_chart_path)

    # Save the classification report as a text file
    classification_report_path = os.path.join(weights_path, f"classification_report.txt")
    save_classification_report(true_labels, val_predicted_ids, class_names, classification_report_path)

def compute_cv_statistics(accuracies, precisions, recalls, f1_scores, use_std_error=False, output_filepath=None):
    """
    Compute the mean and variation (std dev or standard error) for each metric and optionally save the results to a file.
    
    Parameters:
        accuracies (list of float): Accuracy values for each fold.
        precisions (list of float): Precision values for each fold.
        recalls (list of float): Recall values for each fold.
        f1_scores (list of float): F1 score values for each fold.
        use_std_error (bool): If True, compute standard error (std / sqrt(n)); otherwise, compute standard deviation.
        output_filepath (str): If provided, the path to a text file where the metrics will be saved.
    
    The function prints each metric in the format:
        Metric: mean ± variation
    (Metrics are multiplied by 100 to display percentages.)
    """
    metrics = {
        "Accuracy": np.array(accuracies),
        "Precision": np.array(precisions),
        "Recall": np.array(recalls),
        "F1 Score": np.array(f1_scores)
    }
    
    output_lines = []
    for metric_name, values in metrics.items():
        mean_val = np.mean(values)
        # Use ddof=1 for sample standard deviation
        variation = np.std(values, ddof=1)
        if use_std_error:
            variation /= np.sqrt(len(values))
        # Format the output as percentages; adjust if your metrics are already in percentage
        output_lines.append(f"{metric_name}: {mean_val*100:.2f} ± {variation*100:.2f}\n")
    
    metrics_str = "".join(output_lines)
    
    # Print the overall metrics to the console
    print("\nOverall Cross-Validation Metrics:")
    print(metrics_str)
    
    # Save the metrics to a text file if an output file path is provided
    if output_filepath:
        with open(output_filepath, "w") as f:
            f.write("Overall Cross-Validation Metrics:\n")
            f.write(metrics_str)

# %%
def save_confusion_matrix_binary(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                          save_path: str, mpox_index: int = 0) -> None:
    """
    Converts multi-class labels to binary (Mpox vs Other) and plots/saves the confusion matrix.

    Args:
        true_labels (np.ndarray): Array of true class labels (multi-class integers).
        predicted_labels (np.ndarray): Array of predicted class labels (multi-class integers).
        save_path (str): Path to save the confusion matrix plot.
        mpox_index (int): The index corresponding to Mpox. All other labels are considered "Other".
    """
    # Convert multi-class labels to binary: 1 if label equals mpox_index, else 0.
    binary_true = (true_labels == mpox_index).astype(int)
    binary_pred = (predicted_labels == mpox_index).astype(int)
    cm = confusion_matrix(binary_true, binary_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Other", "Mpox"])
    
    # Plot with adjustments
    fig, ax = plt.subplots(figsize=(8, 6))  # Adjust figure size
    disp.plot(cmap=plt.cm.Blues, ax=ax)

    ax.set_title("Confusion Matrix")
    ax.set_xlabel("Predicted label", fontsize=12)
    ax.set_ylabel("True label", fontsize=12)

    # Rotate x-axis labels for better readability and alignment
    plt.xticks(rotation=45, ha='right', rotation_mode='anchor', fontsize=10)
    plt.yticks(rotation=45, ha='right', rotation_mode='anchor', fontsize=10)

    # Prevent labels from being cut off
    plt.tight_layout()

    # Save and close plot
    plt.savefig(save_path, bbox_inches='tight')
    plt.close()

def save_loss_curve_binary(history: Dict[str, Any], save_path: str) -> None:
    """
    Plots and saves the training and validation loss curves.

    Args:
        history (Dict[str, Any]): Dictionary containing training history (loss values).
        save_path (str): Path to save the loss curve plot.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Training Loss', color='blue')
    plt.plot(history['val_loss'], label='Validation Loss', color='orange')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig(save_path)
    plt.close()

def save_evaluation_metrics_binary(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                            predicted_probs: np.ndarray, save_path: str, 
                            mpox_index: int = 0) -> Dict[str, float]:
    """
    Computes and plots evaluation metrics for binary classification (Mpox vs Other).

    Args:
        true_labels (np.ndarray): Array of true class labels (multi-class integers).
        predicted_labels (np.ndarray): Array of predicted class labels (multi-class integers).
        predicted_probs (np.ndarray): Array of predicted probabilities for each class 
                                      (shape: [n_samples, n_classes]).
        save_path (str): Path to save the evaluation metrics bar chart.
        mpox_index (int): The index corresponding to Mpox.

    Returns:
        Dict[str, float]: Dictionary containing computed metrics.
    """
    # Convert to binary labels
    binary_true = (true_labels == mpox_index).astype(int)
    binary_pred = (predicted_labels == mpox_index).astype(int)
    # Use the probability for the Mpox class as the positive probability.
    mpox_probs = predicted_probs[:, mpox_index]

    accuracy = np.mean(binary_true == binary_pred)
    precision = precision_score(binary_true, binary_pred)
    recall = recall_score(binary_true, binary_pred)
    f1 = f1_score(binary_true, binary_pred)
    roc_auc = roc_auc_score(binary_true, mpox_probs)

    metrics = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Sensitivity (Recall)": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc
    }

    # Plot metrics as a bar chart
    plt.figure(figsize=(10, 6))
    bars = plt.bar(metrics.keys(), metrics.values(), 
                   color=['darkturquoise', 'sandybrown', 'hotpink', 'limegreen', 'mediumpurple'])
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.4f}', ha='center', va='bottom')
    plt.title("Evaluation Metrics (Mpox vs Other)")
    plt.ylim([0, 1])
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.ylabel("Score")
    plt.savefig(save_path)
    plt.close()

    return metrics

def save_classification_report_binary(true_labels: np.ndarray, predicted_labels: np.ndarray, 
                               save_path: str, mpox_index: int = 0) -> None:
    """
    Saves the classification report for binary classification (Mpox vs Other).

    Args:
        true_labels (np.ndarray): Array of true class labels (multi-class integers).
        predicted_labels (np.ndarray): Array of predicted class labels (multi-class integers).
        save_path (str): Path to save the classification report.
        mpox_index (int): The index corresponding to Mpox.
    """
    binary_true = (true_labels == mpox_index).astype(int)
    binary_pred = (predicted_labels == mpox_index).astype(int)
    report = classification_report(binary_true, binary_pred, target_names=["Other", "Mpox"], digits=4)
    with open(save_path, "w") as f:
        f.write(report)

def calculate_metrics_binary(true_labels: np.ndarray, predictions: np.ndarray, 
                      mpox_index: int = 0) -> Tuple[float, float, float, float, float]:
    """
    Calculates binary evaluation metrics for Mpox vs Other.
    The multi-class predictions are converted into binary predictions where the positive class 
    is Mpox (identified by mpox_index) and all other classes are negative.

    Args:
        true_labels (np.ndarray): Array of true class labels (multi-class integers).
        predictions (np.ndarray): Array of predicted probabilities (shape: [n_samples, n_classes]).
        mpox_index (int): The index corresponding to Mpox.

    Returns:
        Tuple[float, float, float, float, float]:
            Accuracy, Precision, Recall, F1 Score, and ROC AUC.
    """
    # Convert multi-class predictions to class indices
    predicted_labels_multi = np.argmax(predictions, axis=1)
    # Convert to binary: 1 if Mpox, 0 otherwise.
    binary_true = (true_labels == mpox_index).astype(int)
    binary_pred = (predicted_labels_multi == mpox_index).astype(int)
    mpox_probs = predictions[:, mpox_index]

    accuracy = np.mean(binary_true == binary_pred)
    precision = precision_score(binary_true, binary_pred)
    recall = recall_score(binary_true, binary_pred)
    f1 = f1_score(binary_true, binary_pred)
    auc = roc_auc_score(binary_true, mpox_probs)

    return accuracy, precision, recall, f1, auc

def save_best_model_visuals_binary(history: tf.keras.callbacks.History, model: tf.keras.Model, 
                              val_ds: tf.data.Dataset, weights_path: str, 
                              fold: int, mpox_index: int = 1) -> None:
    """
    Generates and saves evaluation visuals (confusion matrix, loss curve, metrics bar chart,
    and classification report) for binary classification (Mpox vs Other) for the best performing model.

    Args:
        history (tf.keras.callbacks.History): Training history object.
        model (tf.keras.Model): Trained model.
        val_ds (tf.data.Dataset): Validation dataset.
        weights_path (str): Directory path to save visuals.
        fold (int): Current fold number.
        mpox_index (int): The index corresponding to Mpox.
    """
    # Generate predictions for the validation set
    val_predictions = model.predict(val_ds)
    predicted_ids_multi = np.argmax(val_predictions, axis=1)
    true_labels = np.concatenate([y for _, y in val_ds], axis=0)
    
    # Save the confusion matrix
    confusion_matrix_path = os.path.join(weights_path, f"confusion_matrix_binary.png")
    save_confusion_matrix_binary(true_labels, predicted_ids_multi, confusion_matrix_path, mpox_index)
    
    # Save the loss curve
    loss_curve_path = os.path.join(weights_path, f"loss_curve_binary.png")
    save_loss_curve_binary(history.history, loss_curve_path)
    
    # Save evaluation metrics bar chart
    metrics_bar_chart_path = os.path.join(weights_path, f"evaluation_metrics_binary.png")
    save_evaluation_metrics_binary(true_labels, predicted_ids_multi, val_predictions, metrics_bar_chart_path, mpox_index)
    
    # Save the classification report
    classification_report_path = os.path.join(weights_path, f"classification_report_binary.txt")
    save_classification_report_binary(true_labels, predicted_ids_multi, classification_report_path, mpox_index)

# %% [markdown]
# ### Automated Hyperparameter Tuning

# %%
# # Split data into training/validation set for hyperparameter tuning
# train_images_tuning, val_images_tuning, train_labels_tuning, val_labels_tuning = train_test_split(
#     image_paths, labels, test_size=0.1, random_state=42, stratify=labels
# )

# # Define the hypermodel for hyperparameter tuning
# def build_model(hp):
#     base_model = tf.keras.applications.MobileNetV2(
#         input_shape=(img_height, img_width, 3),
#         include_top=False,
#         weights='imagenet'
#     )
#     base_model.trainable = False  # Freeze layers initially
    
#     model = Sequential([
#         base_model,
#         layers.GlobalAveragePooling2D(),
#         layers.Dense(num_classes)
#     ])

#     # Tune hyperparameters
#     learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
#     optimizer = hp.Choice('optimizer', values=['adam', 'sgd'])

#     if optimizer == 'adam':
#         opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
#     else:
#         opt = tf.keras.optimizers.SGD(learning_rate=learning_rate)

#     model.compile(
#         optimizer=opt,
#         loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#         metrics=['accuracy']
#     )
    
#     return model

# # Set up the tuner for hyperparameter tuning
# tuner = kt.RandomSearch(
#     build_model,
#     objective='val_accuracy',  # Optimize for validation accuracy
#     max_trials=10,             # Try 10 different hyperparameter combinations
#     executions_per_trial=1,    # Run each combination once
#     directory='hyperparameter_tuning',
#     project_name='best_hyperparams_tuning'
# )

# # Prepare TensorFlow datasets for training and validation
# train_ds = tf.data.Dataset.from_tensor_slices((train_images_tuning, train_labels_tuning)).batch(batch_size)
# val_ds = tf.data.Dataset.from_tensor_slices((val_images_tuning, val_labels_tuning)).batch(batch_size)

# # Perform the hyperparameter search on the validation set
# tuner.search(train_ds, validation_data=val_ds, epochs=10)

# # Get the best hyperparameters after the search
# best_hyperparams = tuner.get_best_hyperparameters(num_trials=1)[0]

# # Print the best hyperparameters
# print(f"Best Hyperparameters: {best_hyperparams.values}")

# %% [markdown]
# ### Model creation and fine tuning

# %%
# Function to create and compile the model
def create_model(num_classes, config, fine_tune=None):
    # if you are not fine tuning the model, instantiate a new model 
    if(fine_tune == False):         
        # instantiate mobilenet (contains 154 layers)
        base_model = tf.keras.applications.MobileNetV2(
            input_shape=(img_height, img_width, 3),     # set the input it will receive
            include_top=False,                          # do not include top layer to perform transfer learning
            weights='imagenet'                          # load weights from imagenet dataset
        )
        base_model.trainable = False                    # Freeze the base model
        
        # add a layer in order to perform classification on our dataset
        model = Sequential([
            base_model,                         # use base_model as the start of your model
            layers.GlobalAveragePooling2D(),    # add a final layer to perform classification
            layers.Dense(num_classes)           # set the number of possible prediction to the num of classes in dataset
        ])
        
    # select optimizer and learning rate based on configuration
    if config["optimizer"] == "adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["learning_rate"])
    elif config["optimizer"] == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate=config["learning_rate"])
    else:
        raise ValueError(f"Unsupported optimizer: {config['optimizer']}")

    # compile the model
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy']
    )
    
    return model

# fine tune model by unfreezing the layers after the first fine_tune_at layers
def fine_tune_model(base_model, fine_tune_at):
    # Unfreeze the layers starting from fine_tune_at index
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False
    for layer in base_model.layers[fine_tune_at:]:
        layer.trainable = True

# %% [markdown]
# ### Training loop

# %%
fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1s = []


normalization_layer = layers.Rescaling(1.0 / 255)
test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y)).batch(32)

for i, config in enumerate(configs):
    print(f"Training model {i + 1}/{len(configs)} with config: {config}")

    # K-fold Cross Validation
    kfold = StratifiedKFold(n_splits=config['folds'], shuffle=True, random_state=42)
    best_val_f1score = -float('inf')            # Initialize best F1 score with a very low value

    # Define the base path for saving models
    model_subdir = os.path.join(save_dir, f'model{i + 1}')
    os.makedirs(model_subdir, exist_ok=True)

    # Define the base path for saving checkpoints for model
    checkpoint_folder = os.path.join(model_subdir, 'checkpoints')
    os.makedirs(checkpoint_folder, exist_ok=True)

    # Define the base path for saving cthe model with the best f1-score
    best_f1_dir = os.path.join(model_subdir, 'best_f1score_fold')
    os.makedirs(best_f1_dir, exist_ok=True)
    
    # Training and validation loop for each fold
    fold = 1
    best_f1_score = 0
    for train_idx, val_idx in kfold.split(train_val_images, train_val_labels):
        print(f"\nFold {fold}/{config['folds']}...")

        checkpoint_filepath = os.path.join(checkpoint_folder, f'checkpoint_fold{fold}.weights.h5')

        # Create subset datasets for training and validation
        train_images, train_labels = train_val_images[train_idx], train_val_labels[train_idx]
        val_images, val_labels = train_val_images[val_idx], train_val_labels[val_idx]

        computed_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y=train_labels)
        # Create a dictionary mapping each class index to its weight.
        class_weight_dict = {int(cls): weight for cls, weight in zip(np.unique(train_labels), computed_weights)}

        # Convert NumPy arrays back to TensorFlow datasets
        train_ds = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
        val_ds = tf.data.Dataset.from_tensor_slices((val_images, val_labels))

        # Normalize datasets 
        normalization_layer = layers.Rescaling(1./255)
        train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
        val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

        # prefetch data to improve performance by overlapping data preprocessing and model execution and cache the dataset in memory and batch
        AUTOTUNE = tf.data.AUTOTUNE
        train_ds = train_ds.batch(batch_size).cache().prefetch(buffer_size=AUTOTUNE)
        val_ds = val_ds.batch(batch_size).cache().prefetch(buffer_size=AUTOTUNE)

        # Step 1: Train model with frozen layers
        print(f"Training with frozen base layers for {config['epochs']} epochs...")

        # Create and compile model for each fold
        model = create_model(num_classes, config, fine_tune=False) 

        # setup callbacks 
        early_stopping, model_checkpoint, reduce_lr = callbacks_setup(checkpoint_filepath)

        # train the model on the training set until the epochs specified
        history_frozen = model.fit(
            train_ds,                                       # dataset used for training
            validation_data=val_ds,                         # dataset used for validation
            epochs=config['epochs'],                        # epochs used for training
            callbacks=[early_stopping, model_checkpoint, reduce_lr],   # set early stopping to avoid overfitting
            class_weight = class_weight_dict,
            verbose=1
        )

        # load the best weights from ModelCheckpoint after training
        model.load_weights(checkpoint_filepath)

        if(config["fine_tune"] == True):
            # Step 2: Unfreeze layers and fine-tune
            print(f"Unfreezing layers starting from layer {config['fine_tune_at']} for fine-tuning...")
            fine_tune_model(model.layers[0], config['fine_tune_at'])      # fine tune model

            # re-compile the model with a lower learning rate for fine-tuning
            fine_tune_lr = config['learning_rate'] * 0.01

            model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_lr),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy']
            )
                
            print(f"Fine-tuning for {config['fine_tune_epochs']} epochs...")

            # setup callbacks again for fine-tuning phase with a unique checkpoint
            early_stopping, model_checkpoint = callbacks_setup(checkpoint_filepath)
            
            history_fine_tune = model.fit(
                train_ds,                                       # dataset used for training
                validation_data=val_ds,                         # dataset used for validation
                epochs=config['fine_tune_epochs'],                        # epochs used for training
                callbacks=[early_stopping, model_checkpoint],   # set early stopping to avoid overfitting
                verbose=1
            )

            # load weights after fine-tuning
            model.load_weights(checkpoint_filepath)

        # evaluate on validation set after training
        val_predictions = model.predict(val_ds)
        avg_val_loss = model.evaluate(val_ds, verbose=0)[0]
        avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = calculate_metrics(
            np.concatenate([y for _, y in val_ds]), val_predictions
        )

        print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

        test_predictions = model.predict(test_ds)
        avg_test_accuracy, avg_test_precision, avg_test_recall, avg_test_f1, _ = calculate_metrics(
        np.concatenate([y for _, y in test_ds]), test_predictions
        )

        # Append the fold metrics to the lists
        fold_accuracies.append(avg_test_accuracy)
        fold_precisions.append(avg_test_precision)
        fold_recalls.append(avg_test_recall)
        fold_f1s.append(avg_test_f1)

        # -------------------- Optional: Evaluation on Test Dataset --------------------
        # If this fold produces the best F1 score so far, save the model and visuals
        if avg_test_f1 > best_f1_score:
            best_f1_score = avg_test_f1
            # Save the best model (using model.export for TensorFlow SavedModel format)
            model.export(best_f1_dir)
            print(f"Best model updated at Fold {fold} with F1 Score: {best_f1_score:.4f}")
            if config.get('save_metrics', False):
                save_best_model_visuals(history_frozen, model, test_ds, class_names, model_subdir, fold)
                save_best_model_visuals_binary(history_frozen, model, test_ds, model_subdir, fold, 5)

        fold += 1       # Move to the next fold

    output_file_path = os.path.join(model_subdir, "cv_metrics.txt")
    compute_cv_statistics(fold_accuracies, fold_precisions, fold_recalls, fold_f1s,
                        use_std_error=False, output_filepath=output_file_path)

# save metrics after training
# np.save(os.path.join(save_dir, 'train_metrics.npy'), train_metrics)
# np.save(os.path.join(save_dir, 'val_metrics.npy'), val_metrics)
# Out:
# Training model 1/6 with config: {'model_name': 'mobilenet', 'learning_rate': 0.001, 'batch_size': 32, 'image_size': 224, 'optimizer': 'adam', 'epochs': 50, 'save_metrics': True, 'folds': 5, 'fine_tune': False, 'fine_tune_epochs': 25, 'fine_tune_at': 150}
#
# Fold 1/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5134 - loss: 1.2286 - val_accuracy: 0.7546 - val_loss: 0.6893 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7664 - loss: 0.5481 - val_accuracy: 0.7840 - val_loss: 0.5884 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8132 - loss: 0.4317 - val_accuracy: 0.7987 - val_loss: 0.5362 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8419 - loss: 0.3673 - val_accuracy: 0.8129 - val_loss: 0.5023 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8628 - loss: 0.3235 - val_accuracy: 0.8219 - val_loss: 0.4781 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8776 - loss: 0.2909 - val_accuracy: 0.8287 - val_loss: 0.4601 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8876 - loss: 0.2653 - val_accuracy: 0.8318 - val_loss: 0.4464 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8966 - loss: 0.2445 - val_accuracy: 0.8376 - val_loss: 0.4357 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9038 - loss: 0.2271 - val_accuracy: 0.8424 - val_loss: 0.4273 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9103 - loss: 0.2122 - val_accuracy: 0.8481 - val_loss: 0.4206 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9171 - loss: 0.1993 - val_accuracy: 0.8502 - val_loss: 0.4151 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9220 - loss: 0.1880 - val_accuracy: 0.8539 - val_loss: 0.4107 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9281 - loss: 0.1779 - val_accuracy: 0.8550 - val_loss: 0.4072 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9321 - loss: 0.1689 - val_accuracy: 0.8550 - val_loss: 0.4042 - learning_rate: 0.0010
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9362 - loss: 0.1608 - val_accuracy: 0.8560 - val_loss: 0.4019 - learning_rate: 0.0010
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9397 - loss: 0.1533 - val_accuracy: 0.8586 - val_loss: 0.3999 - learning_rate: 0.0010
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9415 - loss: 0.1465 - val_accuracy: 0.8613 - val_loss: 0.3985 - learning_rate: 0.0010
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9449 - loss: 0.1402 - val_accuracy: 0.8628 - val_loss: 0.3972 - learning_rate: 0.0010
# Epoch 19/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9459 - loss: 0.1343 - val_accuracy: 0.8639 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 20/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9476 - loss: 0.1289 - val_accuracy: 0.8655 - val_loss: 0.3956 - learning_rate: 0.0010
# Epoch 21/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9484 - loss: 0.1238 - val_accuracy: 0.8671 - val_loss: 0.3951 - learning_rate: 0.0010
# Epoch 22/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9491 - loss: 0.1191 - val_accuracy: 0.8681 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 23/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9515 - loss: 0.1146 - val_accuracy: 0.8681 - val_loss: 0.3945 - learning_rate: 0.0010
# Epoch 24/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9533 - loss: 0.1103 - val_accuracy: 0.8697 - val_loss: 0.3942 - learning_rate: 0.0010
# Epoch 25/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9542 - loss: 0.1063 - val_accuracy: 0.8702 - val_loss: 0.3941 - learning_rate: 0.0010
# Epoch 26/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9561 - loss: 0.1025 - val_accuracy: 0.8713 - val_loss: 0.3941 - learning_rate: 0.0010
# Epoch 27/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9579 - loss: 0.0990 - val_accuracy: 0.8702 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 28/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9603 - loss: 0.0956 - val_accuracy: 0.8697 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 29/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9621 - loss: 0.0923 - val_accuracy: 0.8707 - val_loss: 0.3941 - learning_rate: 0.0010
# Epoch 30/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9629 - loss: 0.0886 - val_accuracy: 0.8671 - val_loss: 0.4087 - learning_rate: 5.0000e-04
# Epoch 31/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9641 - loss: 0.0867 - val_accuracy: 0.8686 - val_loss: 0.4070 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
#
# Validation: 	Fold 1 - Loss: 0.3940, Accuracy: 0.8702, Precision: 0.8486, Recall: 0.8894, F1 Score: 0.8639, AUC Score: 0.9670
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# INFO:tensorflow:Assets written to: ../saved_models/model1/best_f1score_fold/assets
# INFO:tensorflow:Assets written to: ../saved_models/model1/best_f1score_fold/assets
# Saved artifact at '../saved_models/model1/best_f1score_fold'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_4894')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   131694436744656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426687376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426686992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426687184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426685456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037138704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037139088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698426688528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037131024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037139280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037133328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037132176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037128144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037136784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037137552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098295568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694838033552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694838031056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098294416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098291344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098292880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098296336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098289040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098297104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098300176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098299024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098298256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098300560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036597456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098295184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694098293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036597072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036592464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036593232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036595920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036590160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036586704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036582864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036588240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036587472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036583632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036586512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036584016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036591696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036593616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036585552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036592080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036597648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037161296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037159760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037158992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037160144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037164752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037165136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037163984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037168592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037168976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037167440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037166672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037167824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037171088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037171472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037171280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037170512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694037161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850267664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850266128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850266512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850268048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850266896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850271504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850271888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850270352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850270736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850275344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850275728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850274192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850273424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850274576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850279184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850279568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850277264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850268624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042617872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042618256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693850279760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042624400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042619792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042609808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131695042620560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849880400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849885392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849886544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849871952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849875408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849875792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849874256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849873488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849874640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849880016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849877328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693849872528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662762000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662763728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662763920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662763536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417123600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417124176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693662764688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417124560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417125904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417126096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417125712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417126480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417127824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417128016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417127632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417126864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417128400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417129744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417129936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417129552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417128784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417130320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417131664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417131856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417131472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417130704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417132240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417133584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417133392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417132624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417134160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417135312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417134544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417136080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417137616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417137232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417136464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417139344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131698417138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853933840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853935184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853935376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853934992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853934416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853935760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853937104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853937296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853936912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853936144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853939024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853939216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853938832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853938064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853939600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853940944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853941136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853939984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853942864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853942672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853941904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853943440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853944784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853944592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853943824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853946704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853946512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853945744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853947280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853948624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853947664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854064720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854065488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693853949584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854065872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854067216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854067408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854067024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854066256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854067792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854069136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854069328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854068944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854068176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854070480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693854070864: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Best model updated at Fold 1 with F1 Score: 0.8655
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Fold 2/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.4956 - loss: 1.2504 - val_accuracy: 0.7036 - val_loss: 0.7805 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7637 - loss: 0.5472 - val_accuracy: 0.7478 - val_loss: 0.6615 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8134 - loss: 0.4336 - val_accuracy: 0.7788 - val_loss: 0.5981 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8401 - loss: 0.3703 - val_accuracy: 0.7924 - val_loss: 0.5551 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8575 - loss: 0.3271 - val_accuracy: 0.8071 - val_loss: 0.5246 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8712 - loss: 0.2947 - val_accuracy: 0.8135 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8845 - loss: 0.2691 - val_accuracy: 0.8171 - val_loss: 0.4865 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8943 - loss: 0.2482 - val_accuracy: 0.8198 - val_loss: 0.4742 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9014 - loss: 0.2307 - val_accuracy: 0.8208 - val_loss: 0.4642 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9082 - loss: 0.2157 - val_accuracy: 0.8229 - val_loss: 0.4561 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9129 - loss: 0.2026 - val_accuracy: 0.8271 - val_loss: 0.4493 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9194 - loss: 0.1911 - val_accuracy: 0.8308 - val_loss: 0.4437 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9232 - loss: 0.1809 - val_accuracy: 0.8297 - val_loss: 0.4389 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9261 - loss: 0.1717 - val_accuracy: 0.8313 - val_loss: 0.4349 - learning_rate: 0.0010
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9284 - loss: 0.1634 - val_accuracy: 0.8345 - val_loss: 0.4317 - learning_rate: 0.0010
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9329 - loss: 0.1558 - val_accuracy: 0.8360 - val_loss: 0.4288 - learning_rate: 0.0010
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9356 - loss: 0.1489 - val_accuracy: 0.8376 - val_loss: 0.4265 - learning_rate: 0.0010
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9375 - loss: 0.1425 - val_accuracy: 0.8376 - val_loss: 0.4246 - learning_rate: 0.0010
# Epoch 19/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9400 - loss: 0.1365 - val_accuracy: 0.8387 - val_loss: 0.4231 - learning_rate: 0.0010
# Epoch 20/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9437 - loss: 0.1310 - val_accuracy: 0.8376 - val_loss: 0.4221 - learning_rate: 0.0010
# Epoch 21/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9461 - loss: 0.1259 - val_accuracy: 0.8403 - val_loss: 0.4212 - learning_rate: 0.0010
# Epoch 22/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9497 - loss: 0.1210 - val_accuracy: 0.8418 - val_loss: 0.4204 - learning_rate: 0.0010
# Epoch 23/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9514 - loss: 0.1165 - val_accuracy: 0.8418 - val_loss: 0.4200 - learning_rate: 0.0010
# Epoch 24/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9525 - loss: 0.1122 - val_accuracy: 0.8418 - val_loss: 0.4197 - learning_rate: 0.0010
# Epoch 25/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9553 - loss: 0.1082 - val_accuracy: 0.8450 - val_loss: 0.4195 - learning_rate: 0.0010
# Epoch 26/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9569 - loss: 0.1044 - val_accuracy: 0.8476 - val_loss: 0.4195 - learning_rate: 0.0010
# Epoch 27/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9591 - loss: 0.1008 - val_accuracy: 0.8497 - val_loss: 0.4196 - learning_rate: 0.0010
# Epoch 28/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9595 - loss: 0.0973 - val_accuracy: 0.8497 - val_loss: 0.4199 - learning_rate: 0.0010
# Epoch 29/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9599 - loss: 0.0935 - val_accuracy: 0.8466 - val_loss: 0.4276 - learning_rate: 5.0000e-04
# Epoch 30/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9590 - loss: 0.0914 - val_accuracy: 0.8497 - val_loss: 0.4194 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step
#
# Validation: 	Fold 2 - Loss: 0.4194, Accuracy: 0.8497, Precision: 0.8226, Recall: 0.8816, F1 Score: 0.8441, AUC Score: 0.9659
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#
# Fold 3/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.5168 - loss: 1.1650 - val_accuracy: 0.7599 - val_loss: 0.6698 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7664 - loss: 0.5420 - val_accuracy: 0.7893 - val_loss: 0.5699 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8224 - loss: 0.4290 - val_accuracy: 0.8103 - val_loss: 0.5196 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8443 - loss: 0.3669 - val_accuracy: 0.8182 - val_loss: 0.4864 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8607 - loss: 0.3245 - val_accuracy: 0.8266 - val_loss: 0.4623 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8713 - loss: 0.2925 - val_accuracy: 0.8334 - val_loss: 0.4441 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8812 - loss: 0.2671 - val_accuracy: 0.8376 - val_loss: 0.4295 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8900 - loss: 0.2461 - val_accuracy: 0.8445 - val_loss: 0.4175 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8988 - loss: 0.2284 - val_accuracy: 0.8487 - val_loss: 0.4074 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9054 - loss: 0.2133 - val_accuracy: 0.8523 - val_loss: 0.3987 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9130 - loss: 0.2001 - val_accuracy: 0.8534 - val_loss: 0.3910 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9195 - loss: 0.1885 - val_accuracy: 0.8565 - val_loss: 0.3843 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9240 - loss: 0.1781 - val_accuracy: 0.8581 - val_loss: 0.3784 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9284 - loss: 0.1688 - val_accuracy: 0.8602 - val_loss: 0.3731 - learning_rate: 0.0010
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9331 - loss: 0.1603 - val_accuracy: 0.8623 - val_loss: 0.3683 - learning_rate: 0.0010
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9378 - loss: 0.1526 - val_accuracy: 0.8650 - val_loss: 0.3641 - learning_rate: 0.0010
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9416 - loss: 0.1455 - val_accuracy: 0.8692 - val_loss: 0.3604 - learning_rate: 0.0010
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9447 - loss: 0.1390 - val_accuracy: 0.8713 - val_loss: 0.3570 - learning_rate: 0.0010
# Epoch 19/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9477 - loss: 0.1329 - val_accuracy: 0.8755 - val_loss: 0.3538 - learning_rate: 0.0010
# Epoch 20/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9507 - loss: 0.1272 - val_accuracy: 0.8765 - val_loss: 0.3512 - learning_rate: 0.0010
# Epoch 21/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9522 - loss: 0.1220 - val_accuracy: 0.8776 - val_loss: 0.3488 - learning_rate: 0.0010
# Epoch 22/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9548 - loss: 0.1170 - val_accuracy: 0.8776 - val_loss: 0.3467 - learning_rate: 0.0010
# Epoch 23/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9566 - loss: 0.1124 - val_accuracy: 0.8802 - val_loss: 0.3449 - learning_rate: 0.0010
# Epoch 24/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9591 - loss: 0.1080 - val_accuracy: 0.8807 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 25/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9603 - loss: 0.1039 - val_accuracy: 0.8807 - val_loss: 0.3422 - learning_rate: 0.0010
# Epoch 26/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9615 - loss: 0.1000 - val_accuracy: 0.8828 - val_loss: 0.3412 - learning_rate: 0.0010
# Epoch 27/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9629 - loss: 0.0963 - val_accuracy: 0.8828 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 28/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9641 - loss: 0.0928 - val_accuracy: 0.8833 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 29/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9656 - loss: 0.0895 - val_accuracy: 0.8854 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 30/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9669 - loss: 0.0864 - val_accuracy: 0.8870 - val_loss: 0.3395 - learning_rate: 0.0010
# Epoch 31/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9674 - loss: 0.0834 - val_accuracy: 0.8865 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 32/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9678 - loss: 0.0806 - val_accuracy: 0.8870 - val_loss: 0.3401 - learning_rate: 0.0010
# Epoch 33/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9685 - loss: 0.0779 - val_accuracy: 0.8875 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 34/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9729 - loss: 0.0736 - val_accuracy: 0.8839 - val_loss: 0.3507 - learning_rate: 5.0000e-04
# Epoch 35/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9747 - loss: 0.0716 - val_accuracy: 0.8839 - val_loss: 0.3492 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
#
# Validation: 	Fold 3 - Loss: 0.3395, Accuracy: 0.8870, Precision: 0.8627, Recall: 0.8950, F1 Score: 0.8773, AUC Score: 0.9695
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# INFO:tensorflow:Assets written to: ../saved_models/model1/best_f1score_fold/assets
# INFO:tensorflow:Assets written to: ../saved_models/model1/best_f1score_fold/assets
# Saved artifact at '../saved_models/model1/best_f1score_fold'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_5210')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   131694838034512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492470032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492470800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693632633744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693632630864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492470608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492472144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492472336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492471952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492472720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492474064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492474256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492473872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492473104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492474640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492475984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492476176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492475792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492475024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492476560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492477904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492478096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492477712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492476944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492478480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492480016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492479632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492478864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492480400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492481744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492481936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492481552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492480784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492482320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492483664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492483856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492483472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492482704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492484240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492485584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492483088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492484624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693492485776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490603024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490602256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490603216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490602448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490603984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490605328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490605520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490605136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490607248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490607440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490607056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490606288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490607824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490609168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490609360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490608976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490608208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490609744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490611088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490611280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490610896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490610128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490611664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490613008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490613200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490612816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490612048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490613584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490614928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490615120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490614736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490613968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490616848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490617040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490615888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490617424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490946512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490947088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490617808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490948624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490948240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490947472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490949008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490950352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490950544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490950160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490949392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490950928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490952272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490952464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490952080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490951312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490952848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490954192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490954384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490954000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490953232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490954768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490956112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490956304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490955920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490955152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490956688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490958032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490958224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490957840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490958608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490959952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490960144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490959760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490958992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490961872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490959376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490961680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693490962064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489255056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489257168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489256784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489256016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489685520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489684752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489257936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489684560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489686864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489687056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489686672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489685904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489687440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489688784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693489688976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   131693244115536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244109776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871936208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871935056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871939280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871931216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871931408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871941968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990025552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990021904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990027472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990022096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990952656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990940368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990951888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990943440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990947280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990945744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990939216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990954960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476946448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476949136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476950672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476943376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476946064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476953936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871517968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871518736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871517008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871521808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873262352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871519120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692871518352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873259472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873263312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873264080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873260624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990427792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873267920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692873258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990417232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990417616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990429712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990427024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872813072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872814224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990428176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692990415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872810960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872822864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872819216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872813264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872815376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693669624016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693648589072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693650912336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693663923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693648586000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872817104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693480938384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693482881104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872820752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131692872820944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693482883984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693482884176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693649149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693480942608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693483152336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693480948176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458354832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458349072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694459179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693483157328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458344080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458357136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227572112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458349840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693458356752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227572496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227565584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227566352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227564048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227564432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227557328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227566736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429148560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227556944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693227568656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429161616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429156240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693429153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693477099856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693845234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644527568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644521424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694036594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693665618064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683294032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644522960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693677649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644519120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693650495248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693644517584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693475354320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683283088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693478173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693475364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693650497168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693674005904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693837326992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693246354192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693246363792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693246361296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693246355152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693246358992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448867920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693477826768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448860624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448867152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131694459380432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448866384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693243721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693632631632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448870032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693243712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693243719248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245428368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693243716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693243718096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245417232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245427984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683497424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245074320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476408656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693683501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245081040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245083344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245071440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693476760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693245073744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448504784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448501904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448496144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448497296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448498064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693442152784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693665208464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448511312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693665221136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693442144912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244706320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244709776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693442142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244700560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244709008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693649118224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693649124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693649120144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693244700368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693652688976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693445883152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693652697232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693652703568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693652702032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693445887760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284268880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693445882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284270608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693283786000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693283771216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284274640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693284276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693283781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448131024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693283779088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693283774480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693666000080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   131693448124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Best model updated at Fold 5 with F1 Score: 0.8851
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Overall Cross-Validation Metrics:
# Accuracy: 87.25 ± 1.61
# Precision: 85.25 ± 1.76
# Recall: 88.88 ± 0.61
# F1 Score: 86.67 ± 1.33

# %% [markdown]
# ## Testing

# %%
# test_ds = tf.keras.utils.image_dataset_from_directory(
#     "../data/merged_MSLD/Test",                                  # loads images from the data_root directory
#     image_size=(img_height, img_width),         # resizes all images to (224, 224) pixels
#     batch_size=batch_size,                      # set the batch size
#     shuffle=False,                              # shufle data when loaded
# )

# test_ds = test_ds.unbatch().batch(batch_size, drop_remainder=True)

# test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# for i, config in enumerate(configs):
#     # model = tf.keras.models.load_model(f'../saved_models/model{i+1}/best_f1score_fold')

#     # Load the SavedModel using TFSMLayer, treating it as a Keras layer
#     model_layer = tf.keras.layers.TFSMLayer(f'../saved_models/model{i+1}/best_f1score_fold', call_endpoint='serving_default')
    
#     # Wrap the TFSMLayer in a Sequential model for inference
#     model = tf.keras.Sequential([model_layer])

#     # once training is complete, evaluate on the held-out test set
#     print(f"Evaluating the best model for model{i+1} on the held-out test set...")
#     # test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
#     # test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y)).batch(batch_size)

#     test_predictions = model.predict(test_ds)

#     # Print the shape and type of predictions for debugging
#     # print(f"Predictions shape: {len(test_predictions['output_0'])}, type: {type(test_predictions)}")
#     # print(f"First few predictions: {test_predictions[:5]}")  # Check the first few predictions

#     # avg_test_loss = model.evaluate(test_ds, verbose=0)[0]
#     avg_test_accuracy, avg_test_precision, avg_test_recall, avg_test_f1, avg_test_auc = calculate_metrics(
#         np.concatenate([y for _, y in test_ds]), test_predictions['output_0']
#     )

#     print(f"\nTest Set Evaluation - Accuracy: {avg_test_accuracy:.4f}, Precision: {avg_test_precision:.4f}, Recall: {avg_test_recall:.4f}, F1 Score: {avg_test_f1:.4f}, AUC Score: {avg_test_auc:.4f}\n")
